# %%
import random, time
from paho.mqtt import client as mqtt_client
import json

broker = 'localhost'
port = 1883
topic = "DevtestTrue"
client_id = f'dm_source_id'
# username = 'wildcard'
# password = 'public'

# %%
def connect_mqtt():
    def on_connect(client, userdata, flags, rc):
        if rc == 0:
            print("Connected to MQTT Broker!")
        else:
            print("Failed to connect, return code %d\n", rc)
    # Set Connecting Client ID
    client = mqtt_client.Client(client_id)
    #client.username_pw_set(username, password)
    client.on_connect = on_connect
    client.connect(broker, port)
    return client

# %%
def publish(client):
     msg_count = 0
     while True:
         time.sleep(1)
         msg = "{\"deviceId\":1,\"value\":31.1,\"region\":\"EMEA\",\"timestamp\":1482236627236}"   
         result = client.publish(topic, msg)
         status = result[0]
         if status == 0:
             print(f"Send `{msg}` to topic `{topic}`")
         else:
             print(f"Failed to send message to topic {topic}")
         msg_count += 1

# %%
def run():
    client = connect_mqtt()
    client.loop_start()
    publish(client)

# %%
if __name__ == '__main__':
    run()
# Out:
# Connected to MQTT Broker!
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
# Send `{"deviceId":1,"value":31.1,"region":"EMEA","timestamp":1482236627236}` to topic `DevtestTrue`
