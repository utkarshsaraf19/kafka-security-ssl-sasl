# %%
import random, time
from paho.mqtt import client as mqtt_client

broker = 'localhost'
port = 1883
topic = "/sensor/data"
client_id = f'python-mqtt-{random.randint(0, 1000)}'
# username = 'wildcard'
# password = 'public'

# %%
def connect_mqtt():
    def on_connect(client, userdata, flags, rc):
        if rc == 0:
            print("Connected to MQTT Broker!")
        else:
            print("Failed to connect, return code %d\n", rc)
    # Set Connecting Client ID
    client = mqtt_client.Client(client_id)
    #client.username_pw_set(username, password)
    client.on_connect = on_connect
    client.connect(broker, port)
    return client

# %%
def subscribe(client: mqtt_client):
    def on_message(client, userdata, msg):
        print(msg.payload.decode())
        print(f"Received `{msg.payload.decode()}` from `{msg.topic}` topic")

    client.subscribe(topic)
    client.on_message = on_message

# %%
def run():
    client = connect_mqtt()
    subscribe(client)
    client.loop_forever()

# %%
if __name__ == '__main__':
    run()
# Out:
# Connected to MQTT Broker!
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "19"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "19"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "20"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "20"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "21"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "21"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "22"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "22"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "23"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "23"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "24"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "24"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "25"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "25"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "26"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "26"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "27"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "27"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "28"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "28"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "29"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "29"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "30"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "30"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "31"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "31"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "32"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "32"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "33"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "33"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "34"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "34"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "35"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "35"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "36"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "36"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "37"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "37"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "38"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "38"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "39"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "39"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "40"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "40"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "41"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "41"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "42"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "42"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "43"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "43"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "44"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "44"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "45"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "45"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "46"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "46"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "47"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "47"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "48"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "48"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "49"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "49"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "50"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "50"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "51"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "51"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "52"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "52"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "53"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "53"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "54"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "54"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "55"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "55"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "56"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "56"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "57"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "57"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "58"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "58"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "59"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "59"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "60"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "60"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "61"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "61"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "62"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "62"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "63"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "63"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "64"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "64"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "65"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "65"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "66"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "66"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "67"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "67"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "68"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "68"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "69"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "69"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "70"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "70"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "71"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "71"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "72"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "72"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "73"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "73"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "74"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "74"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "75"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "75"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "76"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "76"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "77"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "77"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "78"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "78"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "79"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "79"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "80"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "80"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "81"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "81"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "82"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "82"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "83"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "83"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "84"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "84"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "85"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "85"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "86"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "86"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "87"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "87"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "88"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "88"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "89"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "89"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "90"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "90"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "91"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "91"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "92"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "92"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "93"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "93"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "94"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "94"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "95"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "95"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "96"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "96"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "97"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "97"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "98"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "98"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "99"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "99"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "100"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "100"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "101"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "101"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "102"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "102"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "103"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "103"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "104"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "104"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "105"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "105"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "106"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "106"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "107"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "107"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "108"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "108"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "109"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "109"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "110"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "110"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "111"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "111"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "112"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "112"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "113"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "113"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "114"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "114"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "115"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "115"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "116"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "116"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "117"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "117"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "118"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "118"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "119"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "119"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "120"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "120"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "121"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "121"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "122"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "122"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "123"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "123"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "124"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "124"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "125"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "125"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "126"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "126"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "127"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "127"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "128"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "128"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "129"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "129"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "130"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "130"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "131"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "131"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "132"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "132"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "133"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "133"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "134"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "134"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "135"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "135"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "136"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "136"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "137"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "137"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "138"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "138"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "139"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "139"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "140"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "140"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "141"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "141"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "142"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "142"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "143"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "143"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "144"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "144"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "145"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "145"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "146"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "146"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "147"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "147"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "148"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "148"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "149"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "149"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "150"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "150"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "151"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "151"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "152"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "152"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "153"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "153"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "154"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "154"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "155"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "155"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "156"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "156"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "157"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "157"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "158"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "158"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "159"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "159"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "160"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "160"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "161"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "161"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "162"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "162"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "163"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "163"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "164"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "164"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "165"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "165"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "166"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "166"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "167"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "167"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "168"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "168"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "169"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "169"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "170"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "170"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "171"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "171"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "172"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "172"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "173"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "173"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "174"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "174"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "175"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "175"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "176"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "176"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "177"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "177"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "178"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "178"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "179"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "179"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "180"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "180"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "181"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "181"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "182"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "182"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "183"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "183"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "184"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "184"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "185"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "185"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "186"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "186"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "187"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "187"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "188"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "188"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "189"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "189"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "190"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "190"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "191"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "191"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "192"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "192"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "193"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "193"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "194"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "194"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "195"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "195"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "196"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "196"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "197"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "197"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "198"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "198"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "199"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "199"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "200"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "200"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "201"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "201"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "202"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "202"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "203"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "203"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "204"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "204"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "205"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "205"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "206"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "206"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "207"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "207"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "208"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "208"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "209"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "209"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "210"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "210"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "211"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "211"}` from `/sensor/data` topic
# ...
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "257"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "257"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "258"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "258"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "259"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "259"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "260"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "260"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "261"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "261"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "262"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "262"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "263"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "263"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "264"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "264"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "265"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "265"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "266"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "266"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "267"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "267"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "268"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "268"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "269"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "269"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "270"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "270"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "271"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "271"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "272"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "272"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "273"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "273"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "274"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "274"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "275"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "275"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "276"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "276"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "277"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "277"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "278"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "278"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "279"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "279"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "280"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "280"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "281"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "281"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "282"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "282"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "283"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "283"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "284"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "284"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "285"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "285"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "286"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "286"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "287"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "287"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "288"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "288"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "289"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "289"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "290"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "290"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "291"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "291"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "292"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "292"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "293"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "293"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "294"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "294"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "295"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "295"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "296"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "296"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "297"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "297"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "298"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "298"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "299"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "299"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "300"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "300"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "301"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "301"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "302"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "302"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "303"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "303"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "304"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "304"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "305"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "305"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "306"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "306"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "307"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "307"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "308"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "308"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "309"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "309"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "310"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "310"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "311"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "311"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "312"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "312"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "313"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "313"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "314"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "314"}` from `/sensor/data` topic
# {"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "315"}
# Received `{"sepalLength": "6.4", "sepalWidth": "3.2", "petalLength": "4.5", "petalWidth": "1.5", "messages": "315"}` from `/sensor/data` topic
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14424\2144978305.py in <module>
#       1 if __name__ == '__main__':
# ----> 2     run()
#
# ~\AppData\Local\Temp\ipykernel_14424\3345853014.py in run()
#       2     client = connect_mqtt()
#       3     subscribe(client)
# ----> 4     client.loop_forever()
#
# c:\users\utkar\appdata\local\programs\python\python37\lib\site-packages\paho_mqtt-1.6.1-py3.7.egg\paho\mqtt\client.py in loop_forever(self, timeout, max_packets, retry_first_connection)
#    1754             rc = MQTT_ERR_SUCCESS
#    1755             while rc == MQTT_ERR_SUCCESS:
# -> 1756                 rc = self._loop(timeout)
#    1757                 # We don't need to worry about locking here, because we've
#    1758                 # either called loop_forever() when in single threaded mode, or
#
# c:\users\utkar\appdata\local\programs\python\python37\lib\site-packages\paho_mqtt-1.6.1-py3.7.egg\paho\mqtt\client.py in _loop(self, timeout)
#    1148
#    1149         try:
# -> 1150             socklist = select.select(rlist, wlist, [], timeout)
#    1151         except TypeError:
#    1152             # Socket isn't correct type, in likelihood connection is lost
#
# KeyboardInterrupt:
